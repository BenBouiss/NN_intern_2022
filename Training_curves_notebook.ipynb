# %%
from Scripts import Trainings
from Scripts import Plotting
from Scripts import Computing_functions
import numpy as np
import timeit
import itertools
import importlib
import os
import glob
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import pickle
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import xarray as xr
import re
import seaborn as sns
import ast
sns.set_context('paper')

# %%
OcT = ['Ocean1', 'Ocean2', 'Ocean3', 'Ocean4']
Var_X1 = ['x', 'y', 'thermalDriving', 'halineDriving', 'iceDraft']
Var_X2 = ['x', 'y', 'temperatureYZ', 'salinityYZ', 'iceDraft']
Var_X_non_position_driving = ['thermalDriving', 'halineDriving', 'iceDraft']
Var_X_non_position = ['temperatureYZ', 'salinityYZ', 'iceDraft']
Var_X_BIG = ['iceDraft', 'Slope_iceDraft', 'Slope_bathymetry', 'Distances', 'Big_T', 'Big_S']
Var_X_Extra = ['iceDraft', 'Slope_iceDraft', 'Slope_bathymetry', 'Distances', 'temperatureYZ', 'salinityYZ']
Var_X_BIG_test = ['iceDraft','Big_T', 'Big_S']

Var_X_BIG_Step2 = ['iceDraft','Big_T', 'Big_S', 'Distances_ground_line', 'Distances_front_line']
Var_X_BIG_Extra = ['iceDraft', 'bathymetry', 'Slope_iceDraft_x', 'Slope_bathymetry_x',
                   'Slope_iceDraft_y', 'Slope_bathymetry_y', 'Big_T', 'Big_S',
                  'Distances_ground_line', 'Distances_front_line']
Var_X_BIG_Slope = ['iceDraft', 'bathymetry', 'Slope_iceDraft', 'Slope_bathymetry', 'Big_T', 'Big_S',
                  'Distances_ground_line', 'Distances_front_line']
Var_X_slopexy = ['iceDraft', 'bathymetry', 'Slope_iceDraft_x', 'Slope_bathymetry_x',
                   'Slope_iceDraft_y', 'Slope_bathymetry_y', 'temperatureYZ', 'salinityYZ',
                  'Distances_ground_line', 'Distances_front_line']

OcTPlus = ['Ocean1', 'Ocean2', 'Ocean3', 'Ocean4', 'CPL_EXP10_rst']
CPLs_test = ['CPL_EXP10_rst', 'CPL_EXP22_rst', 'CPL_EXP23_rst']

ALL_EXP = ['CPL_EXP10_rst','CPL_EXP11_rst', 'CPL_EXP12_rst','CPL_EXP13_rst','CPL_EXP20_rst','CPL_EXP21_rst','CPL_EXP22_rst', 'CPL_EXP23_rst']
Train_oc_exp = ['Ocean1', 'Ocean2', 'Ocean3', 'Ocean4', 'CPL_EXP10_rst','CPL_EXP13_rst', 'CPL_EXP22_rst', 'CPL_EXP23_rst']


NEW = ['IceOcean1r_ElmerIce', 'IceOcean1ra_ElmerIce']
NEW_under100supr = ['IceOcean1r_ElmerIce_under100supr', 'IceOcean1ra_ElmerIce_under100supr']
NEW_fill100 = ['IceOcean1r_ElmerIce_fill100', 'IceOcean1ra_ElmerIce_fill100']
importlib.reload(Plotting)
importlib.reload(Computing_functions)
importlib.reload(Trainings)
# Out:
# PWD : /home/bouissob/Code
# <module 'Scripts.Trainings' from '/home/bouissob/Code/Scripts/Trainings.py'>

# %%
RMSEs = []
Suffix = '_under100supr'
Model_id = 1653044112 # 128Ep, 128x5 Neur entr sur OcT

for oc in ALL_EXP:
    oc+=Suffix
    RMSE = Plotting.Plot_Melt_time_function(ind = 0,save = False, message = 0, Ocean_target = oc,
                Type_tar = 'COM_NEMO-CNRS', NN_attributes = {'Ocean' : OcT, 
                'Uniq_id' : Model_id}, Save_name = '')[0]
    RMSEs.append(RMSE)
# Out:
# Number of model used : 1
# ['CPL_EXP10_rst_under100supr'] : [48.84670538] Gt/yr 1653044112_Ex_Long_training
#
# Number of model used : 1
# ['CPL_EXP11_rst_under100supr'] : [35.16688913] Gt/yr 1653044112_Ex_Long_training
#
# Number of model used : 1
# ['CPL_EXP12_rst_under100supr'] : [28.26491604] Gt/yr 1653044112_Ex_Long_training
#
# Number of model used : 1
# ['CPL_EXP13_rst_under100supr'] : [40.36205873] Gt/yr 1653044112_Ex_Long_training
#
# Number of model used : 1
# ['CPL_EXP20_rst_under100supr'] : [30.29256233] Gt/yr 1653044112_Ex_Long_training
#
# Number of model used : 1
# ['CPL_EXP21_rst_under100supr'] : [30.70472629] Gt/yr 1653044112_Ex_Long_training
#
# Number of model used : 1
# ['CPL_EXP22_rst_under100supr'] : [5.35906286] Gt/yr -1653044112_Ex_Long_training
#
# Number of model used : 1
# ['CPL_EXP23_rst_under100supr'] : [28.59433582] Gt/yr 1653044112_Ex_Long_training

# %%
#Compute_shuffle_benchmark(Oc, Compute_at_ind = False, NN_attributes = {})
Mod = {'Ocean' : OcT, 'Uniq_id' : 1653044112}
li = Computing_functions.Compute_shuffle_benchmark(Oc = OcT, 
            NN_attributes = Mod)
# Out:
# Model selected : /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_128_N_128_128_128_128_128_Ch_0-1653044112_Ex_Long_training
# Starting iceDraft        1/10
# Starting 235 / 239 Ep_128_N_128_128_128_128_128_Ch_0-1653044112_Ex_Long_training
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_6621/1398961045.py in <module>
#       2 Mod = {'Ocean' : OcT, 'Uniq_id' : 1653044112}
#       3 li = Computing_functions.Compute_shuffle_benchmark(Oc = OcT,
# ----> 4             NN_attributes = Mod)
#
# ~/Code/Scripts/Computing_functions.py in Compute_shuffle_benchmark(Oc, Compute_at_ind, NN_attributes, Specific_shuffle)
#     324     for i, shuffle in enumerate(Vars):
#     325         print(f'Starting {shuffle}        {i+1}/{len(Vars)}')
# ...

# %%
#p = f'{Bet_path}Method_Data/COM_NEMO-CNRS/Method_4/IceOcean1ra_ElmerIce_lite.csv'
#df = pd.read_csv(p)

#file = '/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4_CPL_EXP10_rst_CPL_EXP13_rst_CPL_EXP22_rst_CPL_EXP23_rst/Ep_128_N_96_96_96_96_96_Ch_0-1650407902_Ex_'
#Model = Computing_functions.Fetch_model(os.path.join(file, 'model_128.h5'))
#Dataset = Computing_functions.Compute_datas(Model, file, Choix = '0', Ocean_target = 'IceOcean1ra_ElmerIce_under100supr', 
#                        Type_tar = 'COM_NEMO-CNRS', Epoch = 2, message = 0, Compute_at_t = 'ALL', Method = 4)
#Dataset = Dataset.rename({'date' : 'nTime'})
#np = f'{Bet_path}MISOMIP1/IceOcra_mod.nc'
#
#Dataset.to_netcdf(np)
#df.rename({'date' : 'nTime'},axis = 1, inplace = True)
#D = df.set_index(['nTime', 'x', 'y']).to_xarray()
#np = f'{Bet_path}MISOMIP1/IceOcra.nc'
#
#D.to_netcdf(np)

# %%
d = Plotting.Plot_loss_model(save = False, ind = 0, Ocean = OcT, Exact = True, 
                    Second_axis = ['lr'], Forbid_key = ['loss'], Title = False, Uniq_id = 1653044112) 
min(d['val_mse'])
# Out:
# Ep_128_N_128_128_128_128_128_Ch_0-1653044112_Ex_Long_training
# 0.0043545798398554325

# %%
d = Plotting.Plot_loss_model(save = False, ind = 0, Ocean = OcT, Epoch = 80, Exact = True, 
                    Second_axis = ['lr'], Forbid_key = ['loss'], Title = False, Uniq_id = 1649836902) 
min(d['val_mse'])
# Out:
# Ep_80_N_96_96_96_96_96_Ch_0-1649836902_Ex_
# 0.005263857543468475

# %%
d = Plotting.Plot_loss_model(save = False, ind = 0, Ocean = OcT, Exact = True, 
                Forbid_key = ['loss'], Title = False, Uniq_id = 1652989885, Second_axis = ['lr']) 
min(d['val_mse'])
# Out:
# Ep_64_N_32_32_96_96_Ch_0-1652989885_Ex_
# 0.008490506559610367

# %%
Trainings.Get_model_path_json(Epoch = 128, Ocean = OcT, Var = Var_X_BIG_Extra, return_all = True, 
                              Scaling_lr=True, Batch_size=1024)
# Out:
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_128_N_128_128_128_128_128_Ch_0-1650362530_Ex_',
#  '/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_128_N_128_128_128_128_128_Ch_0-1653044112_Ex_Long_training',
#  '/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_128_N_128_128_128_128_128_Ch_0-1653202773_Ex_Drop_Var_bench_128',
#  '/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_128_N_128_128_128_128_128_Ch_0-1653220299_Ex_Drop_Var_bench_128']

# %%
Mod = {'Ocean' : OcT, 'Method_data' : 4, 'Neur' : '32_32_96_96', 'Var' : Var_X_BIG_Extra, 'Epoch' : 32}
Trainings.Get_model_path_json(**Mod)
# Out:
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_32_N_32_32_96_96_Ch_0-1652956285_Ex_']

# %%
d = Plotting.Plot_loss_model(save = False, ind = 0, Ocean = OcT, Exact = True, 
                Forbid_key = ['loss'], Title = False, Uniq_id = 1652956285, ) 
min(d['val_mse'])
# Out:
# Ep_32_N_32_32_96_96_Ch_0-1652956285_Ex_
# 0.013753056526184082

# %%
importlib.reload(Plotting)
importlib.reload(Computing_functions)
importlib.reload(Trainings)
Mod = [{'Ocean' : OcT, 'Uniq_id' :  1652956285 }, {'Ocean' : OcT, 'Uniq_id' : 1653053178},
       {'Ocean' : OcT, 'Uniq_id':  1653053726}, {'Ocean' : OcT, 'Uniq_id' : 1652989885}]
Plotting.Plot_Loss_against_loss(Mods = Mod, Desired_comparaison=['val_mse'], save = False,
                                label = ['No lr changes', 'Method 1', 'Method 2', 'Method 3'], 
                                Desired_length = 64)
#                label = ['No lr changes', 'Lr /5 every 8', 'Lr /2 every 10', 'lr plateau'])
#label = ['No lr changes', 'Lr /5 every 8', 'Lr /2 every 10', 'lr plateau']
# Out:
# PWD : /home/bouissob/Code
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_32_N_32_32_96_96_Ch_0-1652956285_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653053178_Ex_Comparison_multiple_lrschedultech
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653053726_Ex_Comparison_multiple_lrschedultech
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1652989885_Ex_

# %%
RMSE_cur = []
for OC_target in OcT:
    RMSE = Plotting.Plot_Melt_time_function(ind = 0,save = False, message = 0, Ocean_target = OC_target,
            Type_tar = 'COM_NEMO-CNRS', NN_attributes = Mod, Save_name = '', 
            Labels = ['No lr', 'Method1', 'Metho2','Method3' ])
    RMSE_cur.append(RMSE)
# Out:
# Number of model used : 1
# Number of model used : 1_N_32_32_96_96_Ch_0-1652956285_Ex_
# Number of model used : 1_N_32_32_96_96_Ch_0-1653053178_Ex_Comparison_multiple_lrschedultech
# Number of model used : 1_N_32_32_96_96_Ch_0-1653053726_Ex_Comparison_multiple_lrschedultech
# ['Ocean1'] : [0.70689084] Gt/yr _96_96_Ch_0-1652989885_Ex_
#
# Number of model used : 1
# Number of model used : 1_N_32_32_96_96_Ch_0-1652956285_Ex_
# Number of model used : 1_N_32_32_96_96_Ch_0-1653053178_Ex_Comparison_multiple_lrschedultech
# Number of model used : 1_N_32_32_96_96_Ch_0-1653053726_Ex_Comparison_multiple_lrschedultech
# ['Ocean2'] : [0.41900583] Gt/yr _96_96_Ch_0-1652989885_Ex_
#
# Number of model used : 1
# Number of model used : 1_N_32_32_96_96_Ch_0-1652956285_Ex_
# Number of model used : 1_N_32_32_96_96_Ch_0-1653053178_Ex_Comparison_multiple_lrschedultech
# Number of model used : 1_N_32_32_96_96_Ch_0-1653053726_Ex_Comparison_multiple_lrschedultech
# ...

# %%
importlib.reload(Plotting)
importlib.reload(Computing_functions)
importlib.reload(Trainings)
Mod = [{'Ocean' : OcT, 'Uniq_id' :  1652994362 }, {'Ocean' : OcT, 'Uniq_id' : 1653053178},
       {'Ocean' : OcT, 'Uniq_id':  1653053726}, {'Ocean' : OcT, 'Uniq_id' : 1652989885}]
Plotting.Plot_Loss_against_loss(Mods = Mod, Desired_comparaison=['val_mse'], save = False,
                                label = ['No lr changes', 'Method 1', 'Method 2', 'Method 3'])
#                label = ['No lr changes', 'Lr /5 every 8', 'Lr /2 every 10', 'lr plateau'])
#label = ['No lr changes', 'Lr /5 every 8', 'Lr /2 every 10', 'lr plateau']
# Out:
# PWD : /home/bouissob/Code
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1652994362_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653053178_Ex_Comparison_multiple_lrschedultech
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653053726_Ex_Comparison_multiple_lrschedultech
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1652989885_Ex_

# %%
importlib.reload(Plotting)
importlib.reload(Computing_functions)
importlib.reload(Trainings)
Mod = [{'Ocean' : OcT, 'Uniq_id' :  1653033955 }, {'Ocean' : OcT, 'Uniq_id' : 1653053178},
       {'Ocean' : OcT, 'Uniq_id':  1653053726}, {'Ocean' : OcT, 'Uniq_id' : 1652989885}]
Plotting.Plot_Loss_against_loss(Mods = Mod, Desired_comparaison=['val_mse'], save = False,
                                label = ['No lr changes', 'Method 1', 'Method 2', 'Method 3'])
#                label = ['No lr changes', 'Lr /5 every 8', 'Lr /2 every 10', 'lr plateau'])
#label = ['No lr changes', 'Lr /5 every 8', 'Lr /2 every 10', 'lr plateau']
# Out:
# PWD : /home/bouissob/Code
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653033955_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653053178_Ex_Comparison_multiple_lrschedultech
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653053726_Ex_Comparison_multiple_lrschedultech
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1652989885_Ex_

# %%
d = Plotting.Plot_loss_model(save = False, ind = 0, Ocean = OcT, Exact = True, 
                Forbid_key = ['loss'], Title = False, Uniq_id = 1653044112, Second_axis = ['lr']) 
min(d['val_mse'])
# Out:
# Ep_128_N_128_128_128_128_128_Ch_0-1653044112_Ex_Long_training
# 0.0043545798398554325

# %%
d = Plotting.Plot_loss_model(save = False, ind = 0, Ocean = OcT,
                Forbid_key = ['mae', 'val_mae', 'mse', 'val_mse', ], Title = False, Var = Var_X_BIG_Slope, 
                Neur = '32_32_96_96', Scaling_lr = False, index = 1) 
min(d['val_mse'])
# Out:
# Ep_32_N_32_32_96_96_Ch_0-1653405579_Ex_
# 0.012688897550106049

# %%
d = Plotting.Plot_loss_model(save = False, ind = 0, Ocean = OcT,
                Forbid_key = ['loss'], Title = False, Var = Var_X_BIG_Slope, 
                Neur = '32_32_96_96', Scaling_lr = True, index = 2) 
min(d['val_mse'])
# Out:
# Ep_64_N_32_32_96_96_Ch_0-1652949724_Ex_
# 0.010999754071235657

# %%
d = Plotting.Plot_loss_model(save = False, ind = 0, Ocean = OcT,
                Forbid_key = ['mae', 'val_mae', 'mse', 'val_mse', ], Title = False, Var = Var_X_BIG_Extra, Batch_size = 128,
                Neur = '32_32_96_96', Scaling_lr = False, index = 1) 
min(d['val_mse'])
# Out:
# Ep_64_N_32_32_96_96_Ch_0-1653048561_Ex_Long_training
# 0.013351038098335266

# %%
d = Plotting.Plot_loss_model(save = False, ind = 0, Ocean = OcT, Epoch = 64,
                Forbid_key = ['loss'], Title = False, Var = Var_X_BIG_Extra,
                Neur = '32_32_96_96', Scaling_lr = True, index = 0, Batch_size = 128) 
min(d['val_mse'])
# Out:
# Ep_64_N_32_32_96_96_Ch_0-1653041657_Ex_
# 0.00833935383707285

# %%
Trainings.Get_model_path_json(Ocean = OcT, Scaling_lr = False, Var = Var_X_BIG_Extra, 
                              Batch_size = 128, Epoch = 64, return_all = True)
# Out:
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653048561_Ex_Long_training']

# %%
ID = 1653041657
ID = 1652989885

importlib.reload(Plotting)
importlib.reload(Computing_functions)
importlib.reload(Trainings)
Mod = [{'Ocean' : OcT, 'Uniq_id' :  1653041657 }, {'Ocean' : OcT, 'Uniq_id' : 1652989885}, {'Ocean' : OcT, 'Uniq_id' : 1653048561}]
Plotting.Plot_Loss_against_loss(Mods = Mod, Desired_comparaison=['val_mse'], 
                label = ['Batch 128', 'Batch 1024', 'No'])
# Out:
# PWD : /home/bouissob/Code
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653041657_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1652989885_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653048561_Ex_Long_training

# %%
Mod_id = 1653044444 #No lr change
#Mod_id = 1653044112 #Lr plateau change
d = Plotting.Plot_loss_model(save = False, ind = 0, Ocean = OcT, Title = False,
                Uniq_id = Mod_id, Second_axis = [], Forbid_key = ['mse', 'val_mse', 'mae', 'val_mae'])
min(d['val_mse'])
# Out:
# Ep_128_N_128_128_128_128_128_Ch_0-1653044444_Ex_Long_training
# 0.006723865866661072

# %%
#Mod_id = 1653044444 #No lr change
Mod_id = 1653044112 #Lr plateau change
d = Plotting.Plot_loss_model(save = False, ind = 0, Ocean = OcT, Title = False,
                Uniq_id = Mod_id, Second_axis = ['lr'], Forbid_key = ['mse', 'val_mse', 'mae', 'val_mae'])
min(d['val_mse'])
# Out:
# Ep_128_N_128_128_128_128_128_Ch_0-1653044112_Ex_Long_training
# 0.0043545798398554325

# %%
importlib.reload(Plotting)
importlib.reload(Computing_functions)
importlib.reload(Trainings)
Mod = [{'Ocean' : OcT, 'Uniq_id' :  1653048561 }, {'Ocean' : OcT, 'Uniq_id' : 1653053178},
       {'Ocean' : OcT, 'Uniq_id':  1653053726}, {'Ocean' : OcT, 'Uniq_id' : 1652989885}]
Plotting.Plot_Loss_against_loss(Mods = Mod, Desired_comparaison=['val_mse'], 
                label = ['No lr changes', 'Lr / 5 every 8 ', 'Lr changes /2 every 10', 'Lr plateau'])
# Out:
# PWD : /home/bouissob/Code
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653048561_Ex_Long_training
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653053178_Ex_Comparison_multiple_lrschedultech
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653053726_Ex_Comparison_multiple_lrschedultech
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1652989885_Ex_

# %%
Mod = [{'Ocean' : OcT, 'Uniq_id' :  1653048561 }, {'Ocean' : OcT, 'Uniq_id' : 1653053178},
       {'Ocean' : OcT, 'Uniq_id':  1653053726}, {'Ocean' : OcT, 'Uniq_id' : 1652989885}]
for m in Mod[0:1] :
    d = Plotting.Plot_loss_model(save = True, ind = 0, **m, 
     Forbid_key = ['mae', 'val_mae', 'mse', 'val_mse'], Title = False, Second_axis=[]) 
    print(m, min(d['val_mse']))
# Out:
# Ep_64_N_32_32_96_96_Ch_0-1653048561_Ex_Long_training
# {'Ocean': ['Ocean1', 'Ocean2', 'Ocean3', 'Ocean4'], 'Uniq_id': 1653048561} 0.013351038098335266

# %%
Mod_id = 1652989794 #Lr/5
Mod_id = 1652989831 #Lr/2
Mod_id = 1652989885 #plateau
#Mod_id = 1652989784 #Lr/5 2

Mod_id = 1653033955

d = Plotting.Plot_loss_model(save = False, ind = 0, Ocean = OcT, Title = False,
                Neur = '32_32_96_96', Uniq_id = Mod_id, Second_axis = [], Forbid_key = ['mse', 'val_mse', 'mae', 'val_mae'])
min(d['val_mse'])
# Out:
# Ep_64_N_32_32_96_96_Ch_0-1653033955_Ex_
# 0.009630616754293442

# %%
importlib.reload(Plotting)
importlib.reload(Computing_functions)
importlib.reload(Trainings)
Mod = [{'Ocean' : OcT, 'Uniq_id' : 1652738557 }, {'Ocean' : OcT, 'Uniq_id' : 1653048561},
       {'Ocean' : OcT, 'Uniq_id': 1653033955}, {'Ocean' : OcT, 'Uniq_id' : 1653038481}]
Plotting.Plot_Loss_against_loss(Mods = Mod, Desired_comparaison=['val_mse'], 
                label = ['Batch_size 128', 'New batch_size 128', 
                'Batch_size 1024','Batch_size 2048'])
# Out:
# PWD : /home/bouissob/Code
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1652738557_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653048561_Ex_Long_training
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653033955_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653038481_Ex_

# %%
Mod =  {'Ocean' : OcT, 'Var' :  Var_X_BIG_Extra, 'Epoch' : 64, 'Scaling_lr' : False, 'ind' : 5}
d = Plotting.Plot_loss_model(save = False, **Mod,
     Forbid_key = ['mae', 'val_mae', 'val_mse', 'mse'], Title = False, Second_axis=[])
# Out:
# Ep_64_N_32_32_96_96_Ch_0-1652994362_Ex_

# %%
d = Plotting.Plot_loss_model(save = False, ind = 0, **Mod, 
     Forbid_key = ['mae', 'val_mae', 'val_mse', 'mse'],Desired_length = 32, Title = False, Second_axis=[])

# %%
importlib.reload(Plotting)
importlib.reload(Computing_functions)
importlib.reload(Trainings)
Mod = [{'Ocean' : OcT, 'Uniq_id' :  1653048561 }, {'Ocean' : OcT, 'Uniq_id' : 1653053178},
       {'Ocean' : OcT, 'Uniq_id':  1653053726}, {'Ocean' : OcT, 'Uniq_id' : 1652989885},
      {'Ocean' : OcT, 'Uniq_id' : 1653044444 }, {'Ocean' : OcT, 'Uniq_id' : 1653044112}]
Plotting.Plot_Loss_against_loss(Mods = Mod, Desired_comparaison=['val_mse'], 
                label = ['No lr changes', 'Lr / 5 every 8 ', 
                'Lr changes /2 every 10', 'Lr plateau', 'Lr cst more neur', 
                'More neuron lr plateau'])
# Out:
# PWD : /home/bouissob/Code
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653048561_Ex_Long_training
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653053178_Ex_Comparison_multiple_lrschedultech
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653053726_Ex_Comparison_multiple_lrschedultech
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1652989885_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_128_N_128_128_128_128_128_Ch_0-1653044444_Ex_Long_training
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_128_N_128_128_128_128_128_Ch_0-1653044112_Ex_Long_training

# %%
importlib.reload(Plotting)
importlib.reload(Computing_functions)
importlib.reload(Trainings)
Ids = 1652956285
Mod = [{'Ocean' : OcT, 'Uniq_id' : 1653033955 }, {'Ocean' : OcT, 'Uniq_id': 1652989794}, {'Ocean' : OcT, 'Uniq_id' : 1652989831}, 
      {'Ocean' : OcT, 'Uniq_id' : 1652989885}, {'Ocean' : OcT, 'Uniq_id' :  1650362530}]
Plotting.Plot_Loss_against_loss(Mods = Mod, Desired_comparaison=['val_mse'], label = ['No scaling_change', '/5 every 8', 
                                '/2 every10', 'Plateau lr', 'Plateau lr 128N128Ep 1024batch'])
# Out:
# PWD : /home/bouissob/Code
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653033955_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1652989794_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1652989831_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1652989885_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_128_N_128_128_128_128_128_Ch_0-1650362530_Ex_

# %%
d = Plotting.Plot_loss_model(save = False, ind = 1, Ocean = OcT, Epoch = 256, 
     Forbid_key = ['mae', 'val_mae'], Title = False) 
min(d['val_mse'])
# Out:
# Ep_256_N_128_128_128_128_128_Ch_0-1652656582_Ex_Swish_overfit_quest
# 0.08849155902862549

# %%
d = Plotting.Plot_loss_model(save = False, ind = 0, Ocean = OcT, Epoch = 256, 
     Forbid_key = [], Title = False) 
min(d['val_mse'])
# Out:
# Ep_256_N_32_64_32_Ch_0-1652568113_Ex_Same_ind
# 0.09981343150138855

# %%
m = {'Ocean' : OcT, 'Method_data' : 3, 'Neur' : '32_32_96_96'}
p = Trainings.Get_model_path_json(**m)
data = Trainings.Get_model_attributes(p[0])

# %%
d = Plotting.Plot_loss_model(save = True, ind = 2, Ocean = Train_oc_exp, Epoch = 256, 
                    Second_axis = ['lr'], Forbid_key = ['loss'], Title = False) 
min(d['val_mse'])
# Out:
# Ep_256_N_128_128_128_128_128_128_Ch_0-1650873720_Ex_
# 0.02339012920856476

# %%
d = Plotting.Plot_loss_model(save = True, ind = 2, Ocean = Train_oc_exp, Epoch = 256, 
                    Second_axis = ['lr'], Forbid_key = ['loss'], Title = False) 
min(d['val_mse'])
# Out:
# Ep_256_N_128_128_128_128_128_128_Ch_0-1650550616_Ex_
# 0.018472371622920036

# %%
ALL_OC = OcT + ALL_EXP

# %%
#Compute_shuffle_benchmark(Oc, Compute_at_ind = False, NN_attributes = {})
li = Computing_functions.Compute_shuffle_benchmark(Oc = ALL_OC, NN_attributes = {'Epoch' : 128, 'Ocean' : Train_oc_exp, 'Exact' : 1})

# %%
#Compute_shuffle_benchmark(Oc, Compute_at_ind = False, NN_attributes = {})
li = Computing_functions.Compute_shuffle_benchmark(Oc = ALL_OC, NN_attributes = {'Epoch' : 128, 'Ocean' : Train_oc_exp, 'Exact' : 1}, 
                        Specific_shuffle=['bathymetry', 'iceDraft'])
# Out:
# Model selected : /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4_CPL_EXP10_rst_CPL_EXP13_rst_CPL_EXP22_rst_CPL_EXP23_rst/Ep_128_N_96_96_96_96_96_Ch_0-1650407902_Ex_
# Starting ['bathymetry', 'iceDraft']        1/1
# Starting 1195 / 1199p_128_N_96_96_96_96_96_Ch_0-1650407902_Ex_

# %%
li
# Out:
# [[array([ 8.82916951, 41.69153153, 65.55222336, 18.5957667 , 93.95086806,
#          86.25938541, 77.68759608, 62.4523039 , 76.44889091, 76.27607146,
#          38.81191545, 63.43609031]),
#   68.22417654199525,
#   ['bathymetry', 'iceDraft'],
#   ['Ocean1',
#    'Ocean2',
#    'Ocean3',
#    'Ocean4',
#    'CPL_EXP10_rst',
#    'CPL_EXP11_rst',
#    'CPL_EXP12_rst',
#    'CPL_EXP13_rst',
#    'CPL_EXP20_rst',
#    'CPL_EXP21_rst',
#    'CPL_EXP22_rst',
#    'CPL_EXP23_rst']]]

# %%
p = f'{os.getcwd()}/Cached_data/Variables_benchmark_shuffle_ALL.csv'
l = pd.read_csv(p)

# %%
l
# Out:
#                                                RMSEs   RMSE_tot  \
# 0  [24.81582837  3.97520857 11.25519031  3.369516...  12.813023
# 1  [ 25.44062929  35.93092744  63.82333957  11.82...  87.368213
# 2  [ 3.87310283 26.65795988 22.75404144  8.880203...  31.835273
# 3  [ 2.19504549  2.72225055  2.46590429  0.110763...   8.468495
# 4  [49.60478099 12.52313213 14.4869809   0.170388...  25.089848
# 5  [39.34192305 48.71860887 63.32865688  7.209948...  62.153582
# 6  [ 6.98205097  3.18712919  6.42298752  0.459776...   8.239840
# 7  [ 6.06006766  6.07614554  9.04501358  2.256713...  10.893855
#
#                                                  Var  \
# 0                                           iceDraft
# 1                                         bathymetry
# 2                              Distances_ground_line
# 3                               Distances_front_line
# 4  ['T_0', 'T_1', 'T_2', 'T_3', 'T_4', 'T_5', 'T_...
# 5  ['S_0', 'S_1', 'S_2', 'S_3', 'S_4', 'S_5', 'S_...
# ...

# %%
New_l = pd.DataFrame(li, columns = ['RMSEs', 'RMSE_tot', 'Var', 'Oc'])
New_l_2 = pd.DataFrame(New_l.copy(deep = True))
#New_l_2.RMSEs.iloc[0][0] = 1

# %%
New_l = pd.concat([New_l, New_l_2], ignore_index = True)

# %%
New_l
# Out:
#                                                RMSEs   RMSE_tot  \
# 0  [1.0, 41.69153153470277, 65.55222336085063, 18...  68.224177
# 1  [1.0, 41.69153153470277, 65.55222336085063, 18...  68.224177
#
#                       Var                                                 Oc
# 0  [bathymetry, iceDraft]  [Ocean1, Ocean2, Ocean3, Ocean4, CPL_EXP10_rst...
# 1  [bathymetry, iceDraft]  [Ocean1, Ocean2, Ocean3, Ocean4, CPL_EXP10_rst...

# %%
Names = New_l.Oc.iloc[0]

New_l[Names] = New_l.RMSEs.values
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3993/3899022337.py in <module>
#       1 Names = New_l.Oc.iloc[0]
#       2
# ----> 3 New_l[Names] = New_l.RMSEs.values
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3598             self._setitem_frame(key, value)
#    3599         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3600             self._setitem_array(key, value)
#    3601         elif isinstance(value, DataFrame):
#    3602             self._set_item_frame_value(key, value)
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/core/frame.py in _setitem_array(self, key, value)
#    3654
#    3655             else:
# -> 3656                 self._iset_not_inplace(key, value)
#    3657
#    3658     def _iset_not_inplace(self, key, value):
#
# ...

# %%
li
# Out:
# [[array([24.81582837,  3.97520857, 11.25519031,  3.3695166 , 13.76976053,
#          12.82429354, 19.81203354, 12.37150765, 10.09583475,  9.86987515,
#          16.52827889,  8.43118971]),
#   12.813023278635505,
#   'iceDraft',
#   ['Ocean1',
#    'Ocean2',
#    'Ocean3',
#    'Ocean4',
#    'CPL_EXP10_rst',
#    'CPL_EXP11_rst',
#    'CPL_EXP12_rst',
#    'CPL_EXP13_rst',
#    'CPL_EXP20_rst',
#    'CPL_EXP21_rst',
#    'CPL_EXP22_rst',
#    'CPL_EXP23_rst']],
#  [array([ 25.44062929,  35.93092744,  63.82333957,  11.82117734,
#          105.34394053, 106.13110032, 103.38561943,  94.11615449,
#           98.95512195,  99.11241972,  60.70822463,  97.81184002]),
#   87.36821326937789,
#   'bathymetry',
#   ['Ocean1',
#    'Ocean2',
#    'Ocean3',
#    'Ocean4',
#    'CPL_EXP10_rst',
#    'CPL_EXP11_rst',
#    'CPL_EXP12_rst',
#    'CPL_EXP13_rst',
#    'CPL_EXP20_rst',
#    'CPL_EXP21_rst',
#    'CPL_EXP22_rst',
#    'CPL_EXP23_rst']],
# ...

# %%
LI = pd.DataFrame(li, columns = ['RMSEs', 'RMSE_tot', 'Var', 'Oc'])
#LI.to_csv(f'{os.getcwd()}/Cached_data/Variables_benchmark_shuffle_ALL.csv', index = False)

# %%
d2 = Plotting.Plot_loss_model(save = False, ind = 3, Ocean = OcT, Epoch = 80, Exact = 1,
                    Second_axis = ['lr'], Forbid_key = ['loss'], Title = False)
# Out:
# Ep_80_N_128_128_128_128_128_Ch_0-1649850635_Ex_

# %%
RMSEs = []

for oc in NEW_fill100:
    RMSE = Plotting.Plot_Melt_time_function(ind = 1,save = False, message = 0, Ocean_target = oc,
                Type_tar = 'COM_NEMO-CNRS', NN_attributes = {'Ocean' : Train_oc_exp, 
                'Epoch' : 256})[0]
    RMSEs.append(RMSE)
# Out:
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4_CPL_EXP10_rst_CPL_EXP13_rst_CPL_EXP22_rst_CPL_EXP23_rst/Ep_256_N_96_96_96_96_96_Ch_0-1650493497_Ex_']
# ['IceOcean1r_ElmerIce_fill100'] : [15.84272249] Gt/yr 3497_Ex_
#
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4_CPL_EXP10_rst_CPL_EXP13_rst_CPL_EXP22_rst_CPL_EXP23_rst/Ep_256_N_96_96_96_96_96_Ch_0-1650493497_Ex_']
# ['IceOcean1ra_ElmerIce_fill100'] : [4.66934677] Gt/yr 3497_Ex_

# %%
Trainings.Get_model_path_json(return_all = True, Method_data = 4, Ocean = OcT, Epoch = 128)
# Out:
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_128_N_128_128_128_128_128_Ch_0-1650362530_Ex_']

# %%
A = list(OcT)
A.extend(ALL_EXP)
Method4 = []
for oc in A:
    RMSE = Plotting.Plot_Melt_time_function(ind = 1,save = True, message = 0, Ocean_target = oc,
                Type_tar = 'COM_NEMO-CNRS', NN_attributes = {'Ocean' : Train_oc_exp})[0]
    Method4.append([oc, RMSE])
# Out:
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4_CPL_EXP10_rst_CPL_EXP13_rst_CPL_EXP22_rst_CPL_EXP23_rst/Ep_128_N_96_96_96_96_96_Ch_0-1650407902_Ex_']
# ['Ocean1'] : [1.02771387] Gt/yr 6_96_96_96_Ch_0-1650407902_Ex_
#
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4_CPL_EXP10_rst_CPL_EXP13_rst_CPL_EXP22_rst_CPL_EXP23_rst/Ep_128_N_96_96_96_96_96_Ch_0-1650407902_Ex_']
# ['Ocean2'] : [1.08522297] Gt/yr 6_96_96_96_Ch_0-1650407902_Ex_
#
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4_CPL_EXP10_rst_CPL_EXP13_rst_CPL_EXP22_rst_CPL_EXP23_rst/Ep_128_N_96_96_96_96_96_Ch_0-1650407902_Ex_']
# ['Ocean3'] : [0.61868251] Gt/yr 6_96_96_96_Ch_0-1650407902_Ex_
#
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4_CPL_EXP10_rst_CPL_EXP13_rst_CPL_EXP22_rst_CPL_EXP23_rst/Ep_128_N_96_96_96_96_96_Ch_0-1650407902_Ex_']
# ['Ocean4'] : [0.10545162] Gt/yr 6_96_96_96_Ch_0-1650407902_Ex_
#
# ...

# %%
A = list(OcT)
A.extend(ALL_EXP)
Method3 = []
for oc in A:
    RMSE = Plotting.Plot_Melt_time_function(ind = 1,save = False, message = 0, Ocean_target = oc,
                Type_tar = 'COM_NEMO-CNRS', NN_attributes = {'Ocean' : Train_oc_exp , 'Method_data' : 3})[0]
    Method3.append([oc, RMSE])
# Out:
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4_CPL_EXP10_rst_CPL_EXP13_rst_CPL_EXP22_rst_CPL_EXP23_rst/Ep_80_N_96_96_96_96_96_Ch_0-1650386596_Ex_']
# ['Ocean1'] : [1.83901246] Gt/yr _96_96_96_Ch_0-1650386596_Ex_
#
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4_CPL_EXP10_rst_CPL_EXP13_rst_CPL_EXP22_rst_CPL_EXP23_rst/Ep_80_N_96_96_96_96_96_Ch_0-1650386596_Ex_']
# ['Ocean2'] : [1.68681145] Gt/yr _96_96_96_Ch_0-1650386596_Ex_
#
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4_CPL_EXP10_rst_CPL_EXP13_rst_CPL_EXP22_rst_CPL_EXP23_rst/Ep_80_N_96_96_96_96_96_Ch_0-1650386596_Ex_']
# ['Ocean3'] : [0.76580478] Gt/yr _96_96_96_Ch_0-1650386596_Ex_
#
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4_CPL_EXP10_rst_CPL_EXP13_rst_CPL_EXP22_rst_CPL_EXP23_rst/Ep_80_N_96_96_96_96_96_Ch_0-1650386596_Ex_']
# ['Ocean4'] : [0.2550445] Gt/yr 6_96_96_96_Ch_0-1650386596_Ex_
#
# ...

# %%
New_RMSEs = [33.4, 29.61, 35.12, 28.46, 2.25, 16.95, 2.92, 1.61, 5.36, 5.28, 0.19, 1.16]
df = pd.DataFrame(Method3, columns = ['Ocean', 'Method 3'])
df.set_index(['Ocean'], inplace = True)
df['Method 4'] = np.array(Method4)[:,1].astype(float)
df['Method 4 Only EXP'] = New_RMSEs
d = df[['Method 3','Method 4', 'Method 4 Only EXP']].div(df['Method 3'], axis=0) - 1

# %%
divnorm = TwoSlopeNorm(vmin=-0.5, vcenter=0, vmax=2)
fig = plt.figure()
sns.heatmap(d, annot=df, cmap="RdBu_r", cbar=True, robust = False,# norm = divnorm, 
            vmin=min(d.min(axis = 0)), center=0, vmax=2)
plt.savefig(f'{os.getcwd()}/Image_output/Heatmap_RMSE_ALL_exp_ind.png',facecolor = 'white', dpi=300, bbox_inches = "tight")

# %%
#cbar_kws={'shrink' : 1, 'extend' : 'both'}

# %%
for oc in ALL_EXP:
    Plotting.Plot_Melt_time_function(ind = 1,save = False, message = 1, Ocean_target = oc,
                Type_tar = 'COM_NEMO-CNRS', NN_attributes = {'Ocean' : OcT, 'Neur' : '0'})
# Out:
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_8_N_0_Ch_0-1647887298_Ex_Same_ind']
# Data variables used : temperatureYZ salinityYZ iceDraft
# ['Ocean1'] : [5.01746496] Gt/yr
#
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_8_N_0_Ch_0-1647887298_Ex_Same_ind']
# Data variables used : temperatureYZ salinityYZ iceDraft
# ['Ocean2'] : [4.73260904] Gt/yr
#
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_8_N_0_Ch_0-1647887298_Ex_Same_ind']
# Data variables used : temperatureYZ salinityYZ iceDraft
# ['Ocean3'] : [7.313844] Gt/yr
#
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_8_N_0_Ch_0-1647887298_Ex_Same_ind']
# Data variables used : temperatureYZ salinityYZ iceDraft
# ['Ocean4'] : [1.44836733] Gt/yr

# %%
for exp in ALL_EXP:
    Plotting.Plot_Melt_time_function(ind = 0,save = True, message = 0, Ocean_target = exp,
                Type_tar = 'COM_NEMO-CNRS', NN_attributes = {'Epoch' : 80, 'Ocean' : CPLs_test, 'Method_data' : 3})
# Out:
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/CPL_EXP10_rst_CPL_EXP13_rst_CPL_EXP22_rst_CPL_EXP23_rst/Ep_80_N_96_96_96_96_96_Ch_0-1650014524_Ex_']
# ['CPL_EXP10_rst'] : [2.98531428] Gt/yr 96_Ch_0-1650014524_Ex_
#
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/CPL_EXP10_rst_CPL_EXP13_rst_CPL_EXP22_rst_CPL_EXP23_rst/Ep_80_N_96_96_96_96_96_Ch_0-1650014524_Ex_']
# ['CPL_EXP11_rst'] : [10.10988488] Gt/yr 6_Ch_0-1650014524_Ex_
#
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/CPL_EXP10_rst_CPL_EXP13_rst_CPL_EXP22_rst_CPL_EXP23_rst/Ep_80_N_96_96_96_96_96_Ch_0-1650014524_Ex_']
# ['CPL_EXP12_rst'] : [5.32503111] Gt/yr 96_Ch_0-1650014524_Ex_
#
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/CPL_EXP10_rst_CPL_EXP13_rst_CPL_EXP22_rst_CPL_EXP23_rst/Ep_80_N_96_96_96_96_96_Ch_0-1650014524_Ex_']
# ['CPL_EXP13_rst'] : [1.88337536] Gt/yr 96_Ch_0-1650014524_Ex_
#
# ...

# %%
importlib.reload(Plotting)
importlib.reload(Computing_functions)
importlib.reload(Trainings)
# Out:
# <module 'Scripts.Trainings' from '/home/bouissob/Code/Scripts/Trainings.py'>

# %%
A = Plotting.plot_N_side_exp(Trainings.model_NN, Attribs = [{'Epoch' : 50, 'Ocean' : OcT, 'Exact' : True}], ind = 0, T = [500, 700, 800, 900, 1100], 
    Oc_tar = 'CPL_EXP10_rst', Type_tar = 'COM_NEMO-CNRS', Title = ['0'], save = False, sharing = True)
# Out:
# Started computing for /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_50_N_96_96_96_96_96_Ch_0-1649879982_Ex_
# Finished computing for /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_50_N_96_96_96_96_96_Ch_0-1649879982_Ex_

# %%
min(d['val_mse'])
# Out:
# 0.0043874746188521385

# %%
RMSEs, Params, Melts, Modded_melts, Neurs, Oc = Plotting.Plot_Melt_to_Modded_melt(save = False, 
        Save_name = '', message = 0, Ocean_target = OcT, index = 1, 
        NN_attributes = {'Epoch' : 80 , 'Ocean' : OcT, 'Neur' : '128_128_128_128_128'})
# Out:
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_80_N_128_128_128_128_128_Ch_0-1649850635_Ex_']
# Starting 1/1 model Ep_80_N_128_128_128_128_128_Ch_0-1649850635_Ex_
# 0.29466695740339544

# %%
d = Plotting.Plot_loss_model(save = True, ind = 2, Epoch = 80, Ocean = OcT, Neur = '96_96_96_96_96', 
                    Second_axis = ['lr'], Forbid_key = ['loss'], Title = False, 
                    Var = Var_X_BIG_Extra)
# Out:
# Ep_80_N_96_96_96_96_96_Ch_0-1649803015_Ex_

# %%
min(d['val_mse'])
# Out:
# 0.00568192545324564

# %%
d2 = Plotting.Plot_loss_model(save = True, ind = 3, Epoch = 80, Ocean = OcT, Neur = '96_96_96_96_96', 
                    Second_axis = ['lr'], Forbid_key = ['loss'], Title = False, 
                    Var = Var_X_BIG_Extra)
# Out:
# Ep_80_N_96_96_96_96_96_Ch_0-1649836902_Ex_

# %%
min(d2['val_mse'])
# Out:
# 0.005263857543468475

# %%
#%load_ext tensorboard

# %%
#tensorboard --logdir logs/fit

# %%
Plotting.Plot_loss_model(save = False, ind = 2, Epoch = 45, Ocean = OcT, Neur = '96_96_96_96_96', 
                         Drop = '', Extra_n = 'Same_ind', Forbid_key = ['loss', 'mse'])
# Out:
# Ep_45_N_96_96_96_96_96_Ch_0-1649436725_Ex_Same_ind
# {'loss': [0.018892310559749603,
#   0.01583717204630375,
#   0.014552118256688118,
#   0.01376352645456791,
#   0.013145213015377522,
#   0.012847977690398693,
#   0.012555046007037163,
#   0.012264369055628777,
#   0.01192721538245678,
#   0.016034385189414024,
#   0.014651008881628513,
#   0.014811775647103786,
#   0.013982797041535378,
#   0.016322840005159378,
#   0.014500696212053299,
#   0.02138005755841732,
#   0.01652522012591362,
#   4.218611240386963,
#   0.014539025723934174,
#   0.022311517968773842,
#   0.01521099079400301,
#   0.013872990384697914,
#   0.010752509348094463,
#   0.010239084251224995,
#   0.00992836244404316,
#   0.009711393155157566,
#   0.009488812647759914,
#   0.009311268106102943,
#   0.009164734743535519,
#   0.009034453891217709],
#  'mae': [0.04065060243010521,
#   0.03657687082886696,
#   0.03503602743148804,
#   0.0340905524790287,
#   0.03329762443900108,
#   0.03316676616668701,
# ...

# %%
RMSEs, Params, Melts, Modded_melts, Neurs, Oc = Plotting.Plot_Melt_to_Modded_melt(save = False, 
        Save_name = 'No_scaling_method4', message = 0, Ocean_target = OcT, index = 1, 
        NN_attributes = {'Epoch' : 30 , 'Ocean' : OcT, 'Exact' : True, 
        'Scaling_lr' : False})
# Out:
# Ben
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_30_N_32_32_96_96_Ch_0-1648383533_Ex_Same_ind']
# Starting 1/1 model Ep_30_N_32_32_96_96_Ch_0-1648383533_Ex_Same_ind
# 1.671492786713764

# %% [markdown]
# def Hyp_param_list(Ind, Max):
#     List =['1', '4', '8','16', '32', '64', '96', '128']
#     string = []
#     Possible = List[min(6, 3 * Ind + int(Max)) :min(int(Max/ 1.5) + 3 + 2 * Ind, len(List))]
#     if Ind == Max:
#         return Possible
#     else:
#         Next = Hyp_param_list(Ind + 1, Max)
#         return ['_'.join([j, i]) for i in Next for j in Possible]
# li = []
# for i in range(3):
#     li.extend(Hyp_param_list(0, i))
# li

# %%
def Verify_string_tuple(Seqs, extent):
    List = ['1', '4', '8','16', '32', '64', '96', '128']
    seqsT = list(Seqs)
    Min = int(Seqs[0][0])
    for ind, seq in enumerate(Seqs):
        removed = 0
        int_list = [int(i) for i in seq]
        Max = int_list[0]
        for ints in int_list:
            if ints<Max:
                seqsT.remove(seq)
                removed = 1
                break
            else:
                Max = ints
        if extent >= 3 and removed == 0:
            if int_list.count(Min) < int(extent)/2 and int_list.count(Min)!=0:
                seqsT.remove(seq)
    return seqsT
            
def Hyp2(Extent):
    List = ['1', '4', '8','16', '32', '64', '96', '128'] 
    li = List[min(Extent-1 + int(Extent/2), min(len(List)-2, len(List) - 4 + int(Extent/5))):Extent + 3 + int(2/Extent) + int(Extent/5)]
    permut = list(itertools.product(li, repeat = Extent))
    Seq = Verify_string_tuple(permut, Extent)
    return ['_'.join(i) for i in Seq]

# %%
Data = Plotting.Plot_loss_model(save = False, ind = 1, Epoch = 80, Ocean = OcT, Neur = '96_96_96_96_96', 
                         Second_axis = ['lr'], Extra_n = 'Same_ind', Forbid_key = ['loss'], Title = False, Var = Var_X_BIG_Extra)
# Out:
# Ep_80_N_96_96_96_96_96_Ch_0-1649604319_Ex_Same_ind

# %%
Data = Plotting.Plot_loss_model(save = False, ind = 1, Epoch = 30, Ocean = OcTPlus, Neur = '96_96_96_96_96', 
                         Second_axis = ['lr'], Forbid_key = ['loss'], Title = False, Var = Var_X_BIG_Extra)
# Out:
# Ep_30_N_96_96_96_96_96_Ch_0-1649628838_Ex_

# %%
min(Data['val_mse'])
# Out:
# 0.022816404700279236

# %%
Trainings.Get_model_path_json(Ocean = OcT, return_all = True, Var = Var_X_BIG_Extra, 
                              Batch_size = 128, Scaling_lr = True, Scaling_type='Plateau')
# Out:
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653041657_Ex_']

# %%
d = Plotting.Plot_loss_model(Ocean = OcT, Uniq_id =1653038481)
# Out:
# Ep_64_N_32_32_96_96_Ch_0-1653038481_Ex_

# %%
#### Var_X_Big_EXTRA
Mod = [{'Ocean' : OcT, 'Uniq_id' :  1652949724 },
      {'Ocean' : OcT, 'Uniq_id' :  1653405579 },
      {'Ocean' : OcT, 'Uniq_id' :  1652951334 }, {'Ocean' : OcT, 'Uniq_id' : 1653492297}, {'Ocean' : OcT, 'Uniq_id' :  1653533047 }]
Plotting.Plot_Loss_against_loss(Mods = Mod, Desired_comparaison=['val_mse'], save = False, Desired_length=64,
                                label = ['128', '1024 no lr',
                                        '128 no lr', '128 no lr', '128 no lr'])
#                label = ['No lr changes', 'Lr /5 every 8', 'Lr /2 every 10', 'lr plateau'])
#label = ['No lr changes', 'Lr /5 every 8', 'Lr /2 every 10', 'lr plateau']
# Out:
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1652949724_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_32_N_32_32_96_96_Ch_0-1653405579_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_32_N_32_32_96_96_Ch_0-1652951334_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_32_N_32_32_96_96_Ch_0-1653492297_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_32_N_32_32_96_96_Ch_0-1653533047_Ex_BenchVariableInsert

# %%
prop_cycle = plt.rcParams['axes.prop_cycle']
colors = prop_cycle.by_key()['color']
Uniqs = np.unique(['128', '1024', '2048 no lr', '1024 no lr', '1024 no lr',
                                        '128 no lr', '128 no lr', '128 no lr'])

# %%
#### Var_X_Big_EXTRA
Mod = [{'Ocean' : OcT, 'Uniq_id' :  1653041657 }, {'Ocean' : OcT, 'Uniq_id' : 1652989885}, 
       {'Ocean' : OcT, 'Uniq_id' :  1652956285 }, {'Ocean' : OcT, 'Uniq_id' : 1653048561}, {'Ocean' : OcT, 'Uniq_id' :  1653383513 },
      {'Ocean' : OcT, 'Uniq_id' :  1652994362 }, {'Ocean' : OcT, 'Uniq_id' : 1653033955}, {'Ocean' : OcT, 'Uniq_id' : 1653038481},
      ]
Plotting.Plot_Loss_against_loss(Mods = Mod, Desired_comparaison=['val_mse'], save = False, Desired_length=64,
                                label = ['128', '1024', '128 no lr', '128 no lr', '128 no lr',
                                         '1024 no lr', '1024 no lr', '2048 no lr',
                                        ])
#                label = ['No lr changes', 'Lr /5 every 8', 'Lr /2 every 10', 'lr plateau'])
#label = ['No lr changes', 'Lr /5 every 8', 'Lr /2 every 10', 'lr plateau']
# Out:
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653041657_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1652989885_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_32_N_32_32_96_96_Ch_0-1652956285_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653048561_Ex_Long_training
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_32_N_32_32_96_96_Ch_0-1653383513_Ex_Comparemeth3-4
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1652994362_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653033955_Ex_
# /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_64_N_32_32_96_96_Ch_0-1653038481_Ex_

# %%
Data2 = Plotting.Plot_loss_model(save = False, ind = 2, Epoch = 30, Ocean = OcT, Neur = '96_96_96_96_96', 
        Second_axis = ['lr'], Forbid_key = ['loss'], Title = False, Var = Var_X_BIG_Extra, Hybrid = False)
# Out:
# Ep_30_N_96_96_96_96_96_Ch_0-1649246729_Ex_Same_ind

# %%
print(min(Data['val_mse']))
print(min(Data2['val_mse']))
# Out:
# 0.0061595020815730095
# 0.007502823136746883

# %%
Plotting.Plot_loss_model(save = False, ind = 0, Epoch = 30, Ocean = OcT, Neur = '32_32_96_96')

# %%
data = Plotting.Plot_loss_model(save = False, ind = 1, Epoch = 30, Ocean = OcTPlus, 
                    Neur = '96_96_96_96_96',Second_axis = ['lr'], Forbid_key = ['loss', 'mae', 'val_mae', 'val_loss'])
# Out:
# Ep_30_N_96_96_96_96_96_Ch_0-1649628838_Ex_

# %%
print(min(data['val_mse']))
# Out:
# 0.022816404700279236

# %%
Plotting.Plot_loss_model(save = False, ind = 1, Epoch = 6, Ocean = OcT, 
                    Neur = '32_64_64_32', Method_data = 3)

# %%
importlib.reload(Plotting)
importlib.reload(Computing_functions)
importlib.reload(Trainings)
RMSEs, Params, Melts, Modded_melts, Neurs, Oc = Plotting.Plot_Melt_to_Modded_melt(save = False, message = 0, 
    Ocean_target = OcT, NN_attributes = {'Epoch':8, 'Neur' : '64_64_64_96_96', 'Extra_n' : 'Same_ind', 'Ocean':OcT},index = 0, Compute_at_ind = True)
# Out:
# Starting 1/1 model Ep_8_N_64_64_64_96_96_Ch_0-1647192747_Ex_Same_ind

# %%
RMSEs, Params, Melts, Modded_melts, Neurs, Oc = NN.Plot_Melt_to_Modded_melt(save = False, Epoch = 8, 
                Ocean_trained = OcT, message = 0, Ocean_target = OcT, NN_attributes = {'Neur' : '64_64_64_96_96', 
                                                        'Extra_n' : 'Same_ind'}, Compute_at_ind = False)
# Out:
# Starting 1/1 model Ep_8_N_64_64_64_96_96_Ch_0-1647192747_Ex_Same_ind
# Starting 1/1 model Ep_8_N_64_64_64_96_96_Ch_0-1647192747_Ex_Same_ind
# Starting 1/1 model Ep_8_N_64_64_64_96_96_Ch_0-1647192747_Ex_Same_ind
# Starting 1/1 model Ep_8_N_64_64_64_96_96_Ch_0-1647192747_Ex_Same_ind

# %%
importlib.reload(NN)
RMSEs, Params, Melts, Modded_melts, Neurs, Oc = NN.Plot_Melt_to_Modded_melt(save = True, Epoch = 8, 
                Ocean_trained = 'Ocean1', message = 0, Ocean_target = OcT, NN_attributes = {'Neur' : '64_64_64_96_96', 
                'Extra_n' : 'Same_ind', 'Exact' : 1, 'Var' : Var_X_non_position}, Compute_at_ind = False)
# Out:
# Starting 1/1 model Ep_8_N_64_64_64_96_96_Ch_0-1647523521_Ex_Same_ind ,  For Ocean : Ocean4
# 64_64_64_96_96_TrOcean1_TarOcean1-2-3-4_1647526567.png

# %%
importlib.reload(NN)
RMSEs, Params, Melts, Modded_melts, Neurs, Oc = NN.Plot_Melt_to_Modded_melt(save = True, Epoch = 8, 
                Ocean_trained = 'Ocean1', message = 0, Ocean_target = OcT, NN_attributes = {'Neur' : '64_64_64_96_96', 
                'Extra_n' : 'Same_ind', 'Exact' : 1, 'Var' : Var_X_non_position}, Compute_at_ind = True)
# Out:
# Starting 1/1 model Ep_8_N_64_64_64_96_96_Ch_0-1647523521_Ex_Same_ind ,  For Ocean : Ocean4
# 64_64_64_96_96_TrOcean1_TarOcean1-2-3-4_1647526618.png

# %%
importlib.reload(NN)
RMSEs, Params, Melts, Modded_melts, Neurs, Oc = NN.Plot_Melt_to_Modded_melt(save = True, Epoch = 8, 
                Ocean_trained = OcT, message = 0, Ocean_target = OcT, NN_attributes = {'Neur' : '64_64_64_96_96', 
                'Extra_n' : 'Same_ind', 'Exact' : 1, 'Var' : Var_X_non_position}, Compute_at_ind = False)
# Out:
# Starting 1/1 model Ep_8_N_64_64_64_96_96_Ch_0-1647192747_Ex_Same_ind ,  For Ocean : Ocean4
# 64_64_64_96_96_TrOcean1-2-3-4_TarOcean1-2-3-4_1647526690.png

# %%
Dict = {'Ocean1' : 'COLD -> WARM', 'Ocean2' : 'WARM -> COLD', 'Ocean3' : 'WARM -> WARM', 'Ocean4' : 'COLD -> COLD'}

# %%
Dict['Ocean1']
# Out:
# 'COLD -> WARM'
