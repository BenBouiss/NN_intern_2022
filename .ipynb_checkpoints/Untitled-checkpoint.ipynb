# %%
import pandas as pd
import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import os
import glob
from scipy.interpolate import make_interp_spline, BSpline
import re
import ast
import seaborn as sns
from Scripts import Trainings
from Scripts import Plotting
from Scripts import Computing_functions
import importlib
import tensorflow as tf
sns.set_context('paper') 
importlib.reload(Plotting)
importlib.reload(Computing_functions)
importlib.reload(Trainings)
# Out:
# <module 'Scripts.Trainings' from '/home/bouissob/Code/Scripts/Trainings.py'>

# %%
p = '/bettik/bouissob/Method_Data/COM_NEMO-CNRS/Method_4/Ocean1_lite.csv'
df = pd.read_csv(p)

# %%
df.loc[(df.date <= 1) | (df.date >= 230)].date
# Out:
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
#          ...
# 697915    239
# 697916    239
# 697917    239
# 697918    239
# 697919    239
# Name: date, Length: 34896, dtype: int64

# %%
p = f'{os.getcwd()}/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_8_N_0_Ch_0-1651148156_Ex_/model_8.h5'
p_simple = f'{os.getcwd()}/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_8_N_0_Ch_0-1647892530_Ex_Same_ind/model_8.h5'
p_similar = f'{os.getcwd()}/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_8_N_0_Ch_0-1651148926_Ex_/model_8.h5'
mod = tf.keras.models.load_model(p)
mod_simple = tf.keras.models.load_model(p_simple)
mod_similar = tf.keras.models.load_model(p_similar)

# %%
d_super = Plotting.Plot_loss_model(Epoch = 8, Neur = '0', Ocean = OcT)
# Out:
# Ep_8_N_0_Ch_0-1651148156_Ex_

# %%
d_simple = Plotting.Plot_loss_model(ind = 1, Epoch = 8, Neur = '0', Ocean = OcT)
# Out:
# Ep_8_N_0_Ch_0-1647892530_Ex_Same_ind

# %%
d_similar = Plotting.Plot_loss_model(ind = 1, Epoch = 8, Neur = '0', Ocean = OcT)
# Out:
# Ep_8_N_0_Ch_0-1651148926_Ex_

# %%
Var_X_slopexy = ['iceDraft', 'bathymetry', 'Slope_iceDraft_x', 'Slope_bathymetry_x',
                   'Slope_iceDraft_y', 'Slope_bathymetry_y', 'temperatureYZ', 'salinityYZ',
                  'Distances_ground_line', 'Distances_front_line']
df = pd.DataFrame()
df['Weights'] = [i[0] for i in np.array(mod_similar.weights[0])]
df['Var'] = Var_X_slopexy
df.set_index('Var', inplace = True)

# %%
df
# Out:
#                         Weights
# Var
# iceDraft               0.426245
# bathymetry             0.033146
# Slope_iceDraft_x       0.450490
# Slope_bathymetry_x     0.028351
# Slope_iceDraft_y      -0.044332
# Slope_bathymetry_y     0.061578
# temperatureYZ          0.636825
# salinityYZ            -0.491202
# Distances_ground_line -0.007926
# Distances_front_line  -0.197404

# %%
File_path = '/bettik/bouissob/FAVIER_2019/'
Bet_path = '/bettik/bouissob/'
Data_type = 'COM_NEMO-CNRS'
Var_X_BIG_Extra = ['iceDraft', 'bathymetry', 'Slope_iceDraft_x', 'Slope_bathymetry_x',
                   'Slope_iceDraft_y', 'Slope_bathymetry_y', 'Big_T', 'Big_S',
                  'Distances_ground_line', 'Distances_front_line']
OcT = ['Ocean1', 'Ocean2', 'Ocean3', 'Ocean4']
Train_oc_exp = ['Ocean1', 'Ocean2', 'Ocean3', 'Ocean4', 'CPL_EXP10_rst','CPL_EXP13_rst', 'CPL_EXP22_rst', 'CPL_EXP23_rst']
ALL_EXP = ['CPL_EXP10_rst','CPL_EXP11_rst', 'CPL_EXP12_rst','CPL_EXP13_rst','CPL_EXP20_rst','CPL_EXP21_rst','CPL_EXP22_rst', 'CPL_EXP23_rst']

NEW = ['IceOcean1r_ElmerIce', 'IceOcean1ra_ElmerIce']
NEW_under100supr = ['IceOcean1r_ElmerIce_under100supr', 'IceOcean1ra_ElmerIce_under100supr']
NEW_fill100 = ['IceOcean1r_ElmerIce_fill100', 'IceOcean1ra_ElmerIce_fill100']
ALL_OC = OcT + ALL_EXP

# %%
#def Plot_spatial_RMSE(Model_fn, NN_attrib, ind = 0, Oc_tar = 'Ocean1'
#        ,Type_tar = 'COM_NEMO-CNRS', message = 0, save = False, Title = [])

d = Plotting.Plot_spatial_RMSE(Trainings.model_NN, NN_attrib = {'Ocean' : OcT, 
                'Epoch' : 128}, Oc_tar = ['Ocean1'], Type_tar = 'COM_NEMO-CNRS')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_51918/2782091909.py in <module>
#       3
#       4 d = Plotting.Plot_spatial_RMSE(Trainings.model_NN, NN_attrib = {'Ocean' : OcT,
# ----> 5                 'Epoch' : 128}, Oc_tar = ['Ocean1'], Type_tar = 'COM_NEMO-CNRS')
#
# ~/Code/Scripts/Plotting.py in Plot_spatial_RMSE(Model_fn, NN_attrib, ind, Oc_tar, Type_tar, message, save, Title)
#     398     cmap = plt.get_cmap('seismic')
#     399     Datasets = []
# --> 400     File = Get_model_path_json(ind = ind, **NN_attrib)
#     401     Config = Get_model_attributes(File)
#     402     Choix, Epoch = Config['Choix'], Config['Epoch']
#
# TypeError: Get_model_path_json() got an unexpected keyword argument 'ind'

# %%
for f in ALL_EXP:
    print(f'Starting  {f}')
    f_p = f'{Bet_path}Method_Data/COM_NEMO-CNRS/Method_4/{f}_lite.csv'
    df = pd.read_csv(f_p)
    df = df.loc[df.iceDraft >= 100]
    df.to_csv(f'{Bet_path}Method_Data/COM_NEMO-CNRS/Method_4/{f}_under100supr_lite.csv')
# Out:
# Starting  CPL_EXP10_rst
# Starting  CPL_EXP11_rst
# Starting  CPL_EXP12_rst
# Starting  CPL_EXP13_rst
# Starting  CPL_EXP20_rst
# Starting  CPL_EXP21_rst
# Starting  CPL_EXP22_rst
# Starting  CPL_EXP23_rst

# %%
for f in ALL_EXP:
    print(f'Starting  {f}')
    f_p = f'{Bet_path}Method_Data/COM_NEMO-CNRS/Method_4/{f}_lite.csv'
    df = pd.read_csv(f_p)
    df['iceDraft'] = np.where(df['iceDraft'] < 100 , 100, df['iceDraft'])
    df.to_csv(f'{Bet_path}Method_Data/COM_NEMO-CNRS/Method_4/{f}_fill100_lite.csv')
# Out:
# Starting  CPL_EXP10_rst
# Starting  CPL_EXP11_rst
# Starting  CPL_EXP12_rst
# Starting  CPL_EXP13_rst
# Starting  CPL_EXP20_rst
# Starting  CPL_EXP21_rst
# Starting  CPL_EXP22_rst
# Starting  CPL_EXP23_rst

# %%
for Oc in NEW:
    Plotting.Plot_Melt_time_function(Ocean_target = Oc, Nothing = True, save = True,NN_attributes = {'Ocean' : OcT, 
                'Epoch' : 128})
# Out:
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_128_N_128_128_128_128_128_Ch_0-1650362530_Ex_']
# Data variables used : iceDraft bathymetry Distances_ground_line Distances_front_line Slope_iceDraft_x Slope_iceDraft_y Slope_bathymetry_x Slope_bathymetry_y T_0 T_1 T_2 T_3 T_4 T_5 T_6 T_7 T_8 T_9 T_10 T_11 T_12 T_13 T_14 T_15 T_16 T_17 T_18 T_19 T_20 T_21 T_22 T_23 T_24 T_25 T_26 T_27 T_28 T_29 T_30 T_31 T_32 T_33 T_34 T_35 T_36 T_37 T_38 T_39 S_0 S_1 S_2 S_3 S_4 S_5 S_6 S_7 S_8 S_9 S_10 S_11 S_12 S_13 S_14 S_15 S_16 S_17 S_18 S_19 S_20 S_21 S_22 S_23 S_24 S_25 S_26 S_27 S_28 S_29 S_30 S_31 S_32 S_33 S_34 S_35 S_36 S_37 S_38 S_39
# ['IceOcean1r_ElmerIce'] : [19.60981969] Gt/yr
#
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_128_N_128_128_128_128_128_Ch_0-1650362530_Ex_']
# Data variables used : iceDraft bathymetry Distances_ground_line Distances_front_line Slope_iceDraft_x Slope_iceDraft_y Slope_bathymetry_x Slope_bathymetry_y T_0 T_1 T_2 T_3 T_4 T_5 T_6 T_7 T_8 T_9 T_10 T_11 T_12 T_13 T_14 T_15 T_16 T_17 T_18 T_19 T_20 T_21 T_22 T_23 T_24 T_25 T_26 T_27 T_28 T_29 T_30 T_31 T_32 T_33 T_34 T_35 T_36 T_37 T_38 T_39 S_0 S_1 S_2 S_3 S_4 S_5 S_6 S_7 S_8 S_9 S_10 S_11 S_12 S_13 S_14 S_15 S_16 S_17 S_18 S_19 S_20 S_21 S_22 S_23 S_24 S_25 S_26 S_27 S_28 S_29 S_30 S_31 S_32 S_33 S_34 S_35 S_36 S_37 S_38 S_39
# ['IceOcean1ra_ElmerIce'] : [189.5295106] Gt/yr

# %%
for Oc in ALL_EXP:
    Plotting.Plot_Melt_time_function(Ocean_target = Oc, Nothing = True, save = True,NN_attributes = {'Ocean' : OcT, 
                'Epoch' : 128})
# Out:
# ['/home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_128_N_128_128_128_128_128_Ch_0-1650362530_Ex_']
# Starting 1/1 model Ep_128_N_128_128_128_128_128_Ch_0-1650362530_Ex_
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipykernel_41132/3200897002.py in <module>
#       1 for Oc in ALL_EXP:
#       2     Plotting.Plot_Melt_time_function(Ocean_target = Oc, Nothing = True, save = True,NN_attributes = {'Ocean' : OcT,
# ----> 3                 'Epoch' : 128})
#
# ~/Code/Scripts/Plotting.py in Plot_Melt_time_function(ind, save, Nothing, Save_name, Indep, **kwargs)
#      61
#      62 def Plot_Melt_time_function(ind = 0, save = False, Nothing = False,Save_name = '',Indep = True, **kwargs):
# ---> 63     RMSE, _, Melts, Modded_Melts, _, _, Oc_train, Oc_tar, *_ = Compute_RMSE_from_model_ocean(index = ind, **kwargs)
#      64     x = np.arange(1, len(Modded_Melts) + 1)
#      65     if Indep != True:
#
# ~/Code/Scripts/Computing_functions.py in Compute_RMSE_from_model_ocean(Compute_at_ind, Ocean_target, Type_tar, message, index, Time, NN_attributes, Models_paths, shuffle)
#     219                 Comp = Compute_datas(Model,model_p, Choix, Oc, Type_tar, Epoch, message, Compute_at_ind = True, Datas = Datas, shuffle = shuffle)
#     220             else:
# --> 221                 Comp = Compute_datas(Model,model_p, Choix, Oc, Type_tar, Epoch, message, Method = data.get('Method_data'), shuffle = shuffle)
#     222             Melt, Modded_melt, RMSE, Param = Comp
#     223             RMSEs.append(RMSE)
#
# ~/Code/Scripts/Computing_functions.py in Compute_datas(Model, Model_path, Choix, Ocean_target, Type_tar, Epoch, message, Compute_at_t, Compute_at_ind, Datas, Method, shuffle, return_df)
#      99         Data = Datas
#     100     else:
# --> 101         Data = Fetch_data(Ocean_target, Type_tar, Method)
#     102
#     103         #Data[shuffle] = np.random.permutation(Data[shuffle].values)
#
# ~/Code/Scripts/Computing_functions.py in Fetch_data(Ocean_target, Type_tar, Method)
#      30
#      31 def Fetch_data(Ocean_target, Type_tar, Method):
# ---> 32     df = pd.read_csv(Getpath_dataset(Ocean_target, Type_tar, Method))
#      33     return df
#      34
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     486
#     487     with parser:
# --> 488         return parser.read(nrows)
#     489
#     490
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/readers.py in read(self, nrows)
#    1045     def read(self, nrows=None):
#    1046         nrows = validate_integer("nrows", nrows)
# -> 1047         index, columns, col_dict = self._engine.read(nrows)
#    1048
#    1049         if index is None:
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/io/parsers/c_parser_wrapper.py in read(self, nrows)
#     221         try:
#     222             if self.low_memory:
# --> 223                 chunks = self._reader.read_low_memory(nrows)
#     224                 # destructive to chunks
#     225                 data = _concatenate_chunks(chunks)
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read_low_memory()
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# ~/miniconda3/envs/py37/lib/python3.7/site-packages/pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Calling read(nbytes) on source failed. Try engine='python'.

# %%
d = Plotting.Plot_loss_model(save = False, ind = 0, Epoch = 256, Ocean = Train_oc_exp, 
                    Second_axis = ['lr'], Forbid_key = ['loss'], Title = False)
# Out:
# Ep_256_N_96_96_96_96_96_Ch_0-1650493497_Ex_

# %%
for oc in NEW:
    oc = 'IceOcean1ra_ElmerIce'
    A = Plotting.plot_N_side_exp(Trainings.model_NN, Attribs = [{'Ocean' : OcT, 
                'Epoch' : 128}], ind = 0, T = [100, 650, 700, 800, 1150], 
        Oc_tar = oc, Type_tar = 'COM_NEMO-CNRS', Title = ['Ocean trained Oc1-4'], save = True, sharing = True, Only_reference = True)
# Out:
# Started computing for /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_128_N_128_128_128_128_128_Ch_0-1650362530_Ex_
# Finished computing for /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_128_N_128_128_128_128_128_Ch_0-1650362530_Ex_
# Started computing for /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_128_N_128_128_128_128_128_Ch_0-1650362530_Ex_
# Finished computing for /home/bouissob/Code/Auto_model/COM_NEMO-CNRS/Ocean1_Ocean2_Ocean3_Ocean4/Ep_128_N_128_128_128_128_128_Ch_0-1650362530_Ex_

# %%
# 300 represents number of points to make between T.min and T.max
#xnew = np.linspace(T.min(), T.max(), 300) 

#spl = make_interp_spline(T, power, k=3)  # type: BSpline
#power_smooth = spl(xnew)

#plt.plot(xnew, power_smooth)
#plt.show()

# %%
def Vertic_profil(f, T, var = 'temperatureXZ'):
    #plt.figure()
    data = xr.open_dataset(f)
    data = data.assign_coords({'nx': data.x,
                           'ny': data.y,
                           'nz': - data.z,
                           'nTime': data.time})
    T = data[var].isel(nTime = T).isel(nx = len(data.nx) - 1)
    Z = T.nz
    name = re.findall('CPL_(\w+)_rst', f)[0]
    plt.plot(T, Z, label = name)
    return Z

# %%
files = glob.glob(f'{File_path}*')
plt.figure()
T = 1199
for i, f in enumerate(files):
    print(f'Starting {f}   {i}/{len(files)-1}')
    Z = Vertic_profil(f, T)
COLD = [-1.9,-1.9]
WARM = [-1.9, 1]
z = [min(Z).values, max(Z).values]
plt.plot(COLD, z, label = 'COLD')
plt.plot(WARM, z, label = 'WARM')
plt.gca().invert_yaxis()
plt.legend()
plt.xlabel('Temperature(C)')
plt.ylabel('Depth (m)')
plt.title('TemperatureXZ profiles')
plt.savefig(f'Image_output/All_exp_{T}.png', facecolor = 'white', dpi = 300)
# Out:
# Starting /bettik/bouissob/FAVIER_2019/CPL_EXP13_rst_COM_NEMO-CNRS.nc   0/7
# Starting /bettik/bouissob/FAVIER_2019/CPL_EXP23_rst_COM_NEMO-CNRS.nc   1/7
# Starting /bettik/bouissob/FAVIER_2019/CPL_EXP11_rst_COM_NEMO-CNRS.nc   2/7
# Starting /bettik/bouissob/FAVIER_2019/CPL_EXP21_rst_COM_NEMO-CNRS.nc   3/7
# Starting /bettik/bouissob/FAVIER_2019/CPL_EXP10_rst_COM_NEMO-CNRS.nc   4/7
# Starting /bettik/bouissob/FAVIER_2019/CPL_EXP20_rst_COM_NEMO-CNRS.nc   5/7
# Starting /bettik/bouissob/FAVIER_2019/CPL_EXP22_rst_COM_NEMO-CNRS.nc   6/7
# Starting /bettik/bouissob/FAVIER_2019/CPL_EXP12_rst_COM_NEMO-CNRS.nc   7/7

# %%
#plt.figure()
#T = 239
#for i, f in enumerate(files):
#    print(f'Starting {f}   {i}/{len(files)-1}')
#    Z = Vertic_profil(f, T, var = 'salinityXZ')
#COLD = [33.8, 34.55]
#WARM = [33.8, 34.7]
#z = [min(Z).values, max(Z).values]
#plt.plot(COLD, z, label = 'COLD')
#plt.plot(WARM, z, label = 'WARM')
#plt.gca().invert_yaxis()
#plt.legend()
#plt.xlabel('Salinity(PSU)')
#plt.ylabel('Depth (m)')
#plt.title('SalinityXZ profiles')
#plt.savefig(f'Image_output/All_exp_{T}.png', facecolor = 'white')

# %%
Uniq_var = ['iceDraft', 'bathymetry', 'Slope_iceDraft', 'Slope_bathymetry',
                'T(z)', 'S(z)', 'Distances_ground_line', 'Distances_front_line']

# %%
p = f'{os.getcwd()}/Cached_data/Variables_benchmark.csv'
Data = pd.read_csv(p)

# %%
Var = []
RMSE_oc = []
RMSE_tot = []
for index in Data.index:
    cur = Data.loc[index]
    Var.append(ast.literal_eval(Data['Var'].loc[index]))
    RMSE_oc.append(np.array(Data['RMSEs'].loc[index].strip('][').split()).astype(float))
    RMSE_tot.append(float(Data['RMSE_tot'].loc[index]))

# %%
N_V = []
for ind, Vars in enumerate(Var):
    if 'T_0' in Vars:
        for i in range(40):
            Vars.remove(f'T_{i}')
        Vars.append('T(z)')
    if 'S_0' in Vars:
        for i in range(40):
            Vars.remove(f'S_{i}')
        Vars.append('S(z)')
    if 'Slope_iceDraft_x' in Vars:
        Vars.remove('Slope_iceDraft_x')
        Vars.remove('Slope_iceDraft_y')
        Vars.append('Slope_iceDraft')
        
    if 'Slope_bathymetry_x' in Vars:
        Vars.remove('Slope_bathymetry_x')
        Vars.remove('Slope_bathymetry_y')
        Vars.append('Slope_bathymetry')
    N_V.append(Vars)

# %%
Dropped_var = []

for v in N_V:
    dv = []
    for uv in Uniq_var:
        if uv not in v:
            dv.append(uv)
    Dropped_var.append(dv)

# %%
Dropped_var
# Out:
# [['iceDraft'],
#  ['bathymetry'],
#  ['Slope_iceDraft'],
#  ['Slope_bathymetry'],
#  ['T(z)'],
#  ['S(z)'],
#  ['Distances_ground_line'],
#  ['Distances_front_line'],
#  ['T(z)', 'S(z)']]

# %%
df = pd.DataFrame()

# %%
df['Var_drop'] = [ '_'.join(i) for i in Dropped_var]
df['Total RMSE'] = RMSE_tot
df[['Ocean1', 'Ocean2', 'Ocean3', 'Ocean4']] = RMSE_oc

# %%
DF = df.set_index('Var_drop')

# %%
rank = DF.rank(axis = 0, ascending = False)

#plt.savefig(f'{os.getcwd()}/Image_output/Heatmap_RMSE.png',facecolor = 'white')

# %%
d = DF
Min = d.min()
Max = d.max()
d2 = (d - Min) / (Max - Min)
fig, axes = plt.subplots(figsize=(10, 4))
h = sns.heatmap(rank, annot=d, cmap="Blues_r", cbar=False)
#plt.savefig(f'{os.getcwd()}/Image_output/Heatmap_RMSE_Drop.png',facecolor = 'white', dpi=300, bbox_inches = "tight")

# %%
d = DF.loc[DF.index[:-1]]
Min = d.min()
Max = d.max()
d2 = (d - Min) / (Max - Min)
sns.heatmap(d2, annot=d, cmap="Blues", cbar=False)


#plt.savefig(f'{os.getcwd()}/Image_output/Heatmap_RMSE.png',facecolor = 'white', dpi=300, bbox_inches = "tight")
plt.figure()
h = sns.heatmap(rank, annot=DF, cmap="Blues_r", cbar=True)
h.set(ylabel=None)
plt.savefig(f'{os.getcwd()}/Image_output/Heatmap_RMSE_rank.png',facecolor = 'white', dpi=300, bbox_inches = "tight")

# %%
p = f'{os.getcwd()}/Cached_data/Variables_benchmark.csv'
data = pd.read_csv(p)
Var = []
RMSE_oc = []
RMSE_tot = []

for index in data.index:
    cur = data.loc[index]
    if '[' in data['Var'].loc[index]:
        Var.append(ast.literal_eval(data['Var'].loc[index]))
    else:
        Var.append(data['Var'].loc[index])
    RMSE_oc.append(np.array(data['RMSEs'].loc[index].strip('][').split()).astype(float))
    RMSE_tot.append(float(data['RMSE_tot'].loc[index]))

# %%
p = f'{os.getcwd()}/Cached_data/Variables_benchmark_shuffle_ALL.csv'
data = pd.read_csv(p)
Var = []
RMSE_oc = []
RMSE_tot = []

for index in data.index:
    cur = data.loc[index]
    if '[' in data['Var'].loc[index]:
        Var.append(ast.literal_eval(data['Var'].loc[index]))
    else:
        Var.append(data['Var'].loc[index])
    RMSE_oc.append(np.array(data['RMSEs'].loc[index].strip('][').split()).astype(float))
    RMSE_tot.append(float(data['RMSE_tot'].loc[index]))
OC = ast.literal_eval(cur['Oc'])

# %%
Oc = [Ocean if 'CPL' not in Ocean else re.findall('CPL_(\w+)_rst', Ocean)[0] for Ocean in OC]

# %%
Oc
# Out:
# ['Ocean1',
#  'Ocean2',
#  'Ocean3',
#  'Ocean4',
#  'EXP10',
#  'EXP11',
#  'EXP12',
#  'EXP13',
#  'EXP20',
#  'EXP21',
#  'EXP22',
#  'EXP23']

# %%
new_v = []
for v in Var:
    if type(v) == list:
        #print(v)
        if 'T_0' in v:
            new_v.append('T(z)')
        elif 'S_0' in v:
            new_v.append('S(z)')
        elif 'Slope' in v[0]:
            new_v.append(v[0][:-2])
    else:
        new_v.append(v)

# %%
new_v
# Out:
# ['iceDraft',
#  'bathymetry',
#  'Distances_ground_line',
#  'Distances_front_line',
#  'T(z)',
#  'S(z)',
#  'Slope_iceDraft',
#  'Slope_bathymetry']

# %%
df = pd.DataFrame()
df['Var_shuffled'] = new_v
df['Total RMSE'] = RMSE_tot
df[Oc] = RMSE_oc
#df[OcT + ALL_EXP] = RMSE_oc
DF = pd.DataFrame(df).set_index('Var_shuffled')

# %%
d = DF
Min = d.min()
Max = d.max()
d2 = (d - Min) / (Max - Min)
fig, axes = plt.subplots(figsize=(10, 4))
rank = DF.rank(axis = 0, ascending = False)
h = sns.heatmap(rank, annot=d, cmap="Blues_r", cbar=True)
h.set(ylabel=None)
plt.savefig(f'{os.getcwd()}/Image_output/Heatmap_RMSE_shuffle_OcTExp10-13-22-23.png',facecolor = 'white', dpi=300, bbox_inches = "tight")

# %%
ID = 1650362530
ID = 1651150755
p = f'{os.getcwd()}/Cached_data/Shuffle_benchmark/'
ALL_p = glob.glob(f'{p}*{ID}*')
ALL_p
# Out:
# ['/home/bouissob/Code/Cached_data/Shuffle_benchmark/Var_benchmark_1651150755_0_.csv',
#  '/home/bouissob/Code/Cached_data/Shuffle_benchmark/Var_benchmark_1651150755_1_.csv',
#  '/home/bouissob/Code/Cached_data/Shuffle_benchmark/Var_benchmark_1651150755_2_.csv',
#  '/home/bouissob/Code/Cached_data/Shuffle_benchmark/Var_benchmark_1651150755_3_.csv',
#  '/home/bouissob/Code/Cached_data/Shuffle_benchmark/Var_benchmark_1651150755_4_.csv']

# %%
def Convert_var(Var):
    new_v = []
    for v in Var:
        if '[' in v:
            v = ast.literal_eval(v)
        if type(v) == list:
            #print(v)
            if 'T_0' in v:
                new_v.append('T(z)')
            elif 'S_0' in v:
                new_v.append('S(z)')
            elif 'Slope' in v[0]:
                new_v.append(v[0][:-2])
            else:
                new_v.append('-'.join(v))
        else:
            new_v.append(v)
    return new_v

# %%
#Convert_var(df['Var_shuffled'])

# %%
#ast.literal_eval(df['Var_shuffled'].loc[8])

# %%
li = []
for f in ALL_p:
    df = pd.read_csv(f)
    df['Var_shuffled'] = Convert_var(np.array(df['Var_shuffled']))
    df.set_index('Var_shuffled', inplace = True)
    li.append(df)

# %%
A = pd.concat(li).groupby(level=0).mean()
A = A.loc[li[0].index]

# %%
d = A
fig = plt.figure(figsize = (15,5))
Min = d.min()
Max = d.max()
d2 = (d - Min) / (Max - Min)
rank = A.rank(axis = 0, ascending = False)
sns.heatmap(rank, cmap = 'Blues_r', annot = A, fmt='.3g')
# Out:
# <AxesSubplot:ylabel='Var_shuffled'>

# %%
ID
# Out:
# 1651150755
