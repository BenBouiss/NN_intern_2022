# %%
import NN
import numpy as np
import timeit
import itertools
import importlib

# %%
OcT = ['Ocean1', 'Ocean2', 'Ocean3', 'Ocean4']
Var_X1 = ['x', 'y', 'thermalDriving', 'halineDriving', 'iceDraft']
Var_X2 = ['x', 'y', 'temperatureYZ', 'salinityYZ', 'iceDraft']
Var_X_non_position = ['temperatureYZ', 'salinityYZ', 'iceDraft']

# %%
def Hyp_param_list(Ind, Max):
    List =['1', '4', '8','16', '32', '64', '96', '128']
    string = []
    Possible = List[min(6, 3 * Ind + int(Max)) :min(int(Max/ 1.5) + 3 + 2 * Ind, len(List))]
    if Ind == Max:
        return Possible
    else:
        Next = Hyp_param_list(Ind + 1, Max)
        return ['_'.join([j, i]) for i in Next for j in Possible]

# %%
li = []
for i in range(3):
    li.extend(Hyp_param_list(0, i))
li
# Out:
# ['1', '4', '8', '4_32', '8_32', '8_64_96', '16_64_96', '8_64_128', '16_64_128']

# %%
def Verify_string_tuple(Seqs, extent):
    List = ['1', '4', '8','16', '32', '64', '96', '128', '256']
    seqsT = list(Seqs)
    Min = int(Seqs[0][0])
    for ind, seq in enumerate(Seqs):
        removed = 0
        int_list = [int(i) for i in seq]
        Max = int_list[0]
        for ints in int_list:
            if ints<Max:
                seqsT.remove(seq)
                removed = 1
                break
            else:
                Max = ints
        if extent >= 3 and removed == 0:
            if int_list.count(Min) < int(extent)/2 and int_list.count(Min)!=0:
                seqsT.remove(seq)
    return seqsT
            
def Hyp2(Extent):
    List = ['1', '4', '8','16', '32', '64', '96', '128', '256'] 
    li = List[min(Extent-1 + int(Extent/2), min(len(List)-2, len(List) - 3 + int(Extent/5))):Extent+3 + int(2/Extent)]
    permut = list(itertools.product(li, repeat = Extent))
    Seq = Verify_string_tuple(permut, Extent)
    return ['_'.join(i) for i in Seq]

# %%
Hyp2(6)
# Out:
# ['128_128_128_128_128_128',
#  '128_128_128_128_128_256',
#  '128_128_128_128_256_256',
#  '128_128_128_256_256_256',
#  '256_256_256_256_256_256']

# %%
B = A[0]
C = [int(i) for i in B]

# %%
C.count(64)
# Out:
# 5

# %%
li_poss = ['32', '64']
extent = 1
LI = li_poss
list(itertools.product(LI, repeat = 2))
# Out:
# [('32', '32'), ('32', '64'), ('64', '32'), ('64', '64')]

# %%
List = ['1', '4', '8','16', '32', '64', '96', '128']

# %%
List[1:5]
# Out:
# ['4', '8', '16', '32']

# %%
List = ['1', '2', '4', '8', '16', '32', '64']

# %%
import NN
import os
import importlib
import glob
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pickle

# %%
OcT = ['Ocean1', 'Ocean2', 'Ocean3', 'Ocean4']

# %%
#def Compute_data_for_plotting(Epoch = 4, Ocean_trained = 'Ocean1', Type_trained = 'COM_NEMO-CNRS', 
#             Ocean_target = 'Ocean1', Type_tar = 'COM_NEMO-CNRS', message = 1, index = None, **NN_attributes):
importlib.reload(NN)
Rm1, Param1, Neur1,t = NN.Plot_RMSE_to_param(Epoch = 8, Ocean_trained = OcT, message = 0, Ocean_target = 'Ocean1', Time = True
                , NN_attributes = {'Var' : Var_X_non_position, 'Exact':1, 'Extra_n' : 'Same_ind'})
# Out:
# Starting 46/46 model Ep_8_N_128_128_128_128_128_Ch_0-1647209841_Ex_Same_ind

# %%
Rm, Param, Neur = NN.Plot_RMSE_to_param(Epoch = 8, Ocean_trained = OcT, message = 0, Ocean_target = 'Ocean2'
                , NN_attributes = {'Var' : Var_X_non_position, 'Exact':1, 'Extra_n' : 'Same_ind'})
# Out:
# Starting 46/46 model Ep_8_N_128_128_128_128_128_Ch_0-1647209841_Ex_Same_ind

# %%
Rm3, Param3, Neur3, t3 = NN.Plot_RMSE_to_param(Epoch = 8, Ocean_trained = OcT, message = 0, Ocean_target = 'Ocean3', Time = True
                , NN_attributes = {'Var' : Var_X_non_position, 'Exact':1, 'Extra_n' : 'Same_ind'})
# Out:
# Starting 46/46 model Ep_8_N_128_128_128_128_128_Ch_0-1647209841_Ex_Same_ind

# %%
RM = Rm1 + Rm + Rm3

# %%
Neur[RM.argmin()]
# Out:
# '64_64_64_96_96'

# %%
Neur[-2]
# Out:
# '96_128_128_128_128'

# %%
Dataset = 'Ocean1'
Oc_mod_type = 'COM_NEMO-CNRS'
Bet_path = '/bettik/bouissob/'
D_path = os.path.join(Bet_path, 'Data', 'data_{}_{}.csv'.format(Dataset, Oc_mod_type))

# %%
Datasets = ['Ocean1', 'Ocean2', 'Ocean3', 'Ocean4']
li = []
for Ind, Dataset in enumerate(Datasets):
    D_path = os.path.join(Bet_path, 'Data', 'data_{}_{}.csv'.format(Dataset, Oc_mod_type))
    df = pd.read_csv(D_path)
    df['Oc'] = Ind
    li.append(df)
DF = pd.concat(li, ignore_index= True)
Masks = os.path.join(os.getcwd(), 'Auto_model', 'tmp', '_'.join(Datasets), 'ind_1646995963.csv')

# %%
# Out:
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
#           ..
# 9353911    3
# 9353912    3
# 9353913    3
# 9353914    3
# 9353915    3
# Name: Oc, Length: 9353916, dtype: int64

# %%
importlib.reload(NN)
NN.Plot_loss_model(ind = 0, Epoch = 8, Ocean = OcT, Neur = '64_64_64_96_128')

# %%
NN.Plot_loss_model(ind = 0, Epoch = 8, Ocean = OcT, Neur = '64_64_64_96_96', Extra_n = 'Same_ind')

# %%
NN.Plot_loss_model(ind = 0, Epoch = 8, Ocean = OcT, Neur = '96_128_128_128_128')

# %%
NN.Plot_loss_model(ind = 0, Epoch = 8, Ocean = OcT, Neur = '128_128_128_128_128')
